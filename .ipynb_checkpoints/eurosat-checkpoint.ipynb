# %% [markdown]
# <a href="https://colab.research.google.com/github/robertaparna/snn-transfer-learning/blob/main/eurosat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install snntorch
# !pip install pytorch_lightning
# !pip install lightning-bolts
# Out:
# Collecting snntorch
#   Downloading snntorch-0.8.1-py2.py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from snntorch) (2.2.1+cu121)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from snntorch) (2.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from snntorch) (3.7.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from snntorch) (1.25.2)
# Collecting nir (from snntorch)
#   Downloading nir-1.0.1-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 8.7 MB/s eta 0:00:00
# Collecting nirtorch (from snntorch)
#   Downloading nirtorch-1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.13.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 42.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 71.0 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 974.3 kB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.0 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 9.0 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 14.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.1.0->snntorch)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.8 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.1.0->snntorch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.1.0->snntorch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 52.5 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->snntorch) (2.8.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from nir->snntorch) (3.9.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->snntorch) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->snntorch) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->snntorch) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.1.0->snntorch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.1.0->snntorch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nir, nvidia-cusolver-cu12, nirtorch, snntorch
# Successfully installed nir-1.0.1 nirtorch-1.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 snntorch-0.8.1
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.2.1-py3-none-any.whl (801 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.6/801.6 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.3.2-py3-none-any.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.10.0)
# Collecting lightning-utilities>=0.8.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (3.9.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch_lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch_lightning) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->pytorch_lightning) (12.4.127)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch_lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch_lightning) (1.3.0)
# Installing collected packages: lightning-utilities, torchmetrics, pytorch_lightning
# Successfully installed lightning-utilities-0.11.2 pytorch_lightning-2.2.1 torchmetrics-1.3.2
# Collecting lightning-bolts
#   Downloading lightning_bolts-0.7.0-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightning-bolts) (1.25.2)
# Collecting pytorch-lightning<2.0.0,>1.7.0 (from lightning-bolts)
#   Downloading pytorch_lightning-1.9.5-py3-none-any.whl (829 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.10/dist-packages (from lightning-bolts) (1.3.2)
# Requirement already satisfied: lightning-utilities>0.3.1 in /usr/local/lib/python3.10/dist-packages (from lightning-bolts) (0.11.2)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning-bolts) (0.17.1+cu121)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from lightning-bolts) (2.15.2)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>0.3.1->lightning-bolts) (24.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>0.3.1->lightning-bolts) (67.7.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>0.3.1->lightning-bolts) (4.10.0)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2023.6.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (1.62.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (2.31.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->lightning-bolts) (3.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.10.0->lightning-bolts) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (12.4.127)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (3.9.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->lightning-bolts) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->lightning-bolts) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->lightning-bolts) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->lightning-bolts) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->lightning-bolts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->lightning-bolts) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->lightning-bolts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=2.9.1->lightning-bolts) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->lightning-bolts) (2.1.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (4.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->lightning-bolts) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->lightning-bolts) (3.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->pytorch-lightning<2.0.0,>1.7.0->lightning-bolts) (1.3.0)
# Installing collected packages: pytorch-lightning, lightning-bolts
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.2.1
#     Uninstalling pytorch-lightning-2.2.1:
#       Successfully uninstalled pytorch-lightning-2.2.1
# Successfully installed lightning-bolts-0.7.0 pytorch-lightning-1.9.5

# %%
from torch.utils.data import Dataset
import os
import pandas as pd
from torchvision.io import read_image
from PIL import Image
from pathlib import Path
import torch
from torch.utils.data import Dataset
from torchvision import datasets
from torchvision.transforms import ToTensor
from torchvision.io import read_image
import matplotlib.pyplot as plt
from torchvision.models import resnet

import snntorch as snn
from snntorch import spikeplot as splt
from snntorch import spikegen
import numpy as np
import snntorch as snn
from snntorch import surrogate
from snntorch import functional as SF
from snntorch import utils

from argparse import ArgumentParser
from itertools import chain

import torch
from torch import nn, optim
import torch.nn.functional as F
import torchvision
from pytorch_lightning import LightningModule
from pl_bolts.metrics import precision_at_k

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, random_split
from torchvision import datasets
from torchvision import transforms as T
import torch.nn.functional as F

from copy import deepcopy

import itertools

import time
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:92: UnderReviewWarning: The feature FeatureMapContrastiveTask is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   contrastive_task: Union[FeatureMapContrastiveTask] = FeatureMapContrastiveTask("01, 02, 11"),
# /usr/local/lib/python3.10/dist-packages/pl_bolts/losses/self_supervised_learning.py:228: UnderReviewWarning: The feature AmdimNCELoss is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   self.nce_loss = AmdimNCELoss(tclip)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Mounted at /content/gdrive

# %%
# !unzip gdrive/MyDrive/EuroSAT_RGB.zip
# Out:
# Voogesituse väljund on kärbitud viimase 5000 reani.
#   inflating: EuroSAT_RGB/Residential/Residential_489.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1573.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_270.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_516.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2683.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_502.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2697.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_264.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2867.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2873.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_258.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2126.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1349.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2640.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2898.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2654.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2132.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1413.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1375.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1361.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2668.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1407.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1188.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2481.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_714.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1836.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1822.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2495.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_700.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_728.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2442.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2324.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2330.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1639.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2456.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1177.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_933.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2318.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1611.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1605.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_927.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1163.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1604.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1162.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_926.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_932.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1176.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1610.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2319.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1638.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2331.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2457.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2443.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_2325.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_729.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_1823.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_701.jpg
#   inflating: EuroSAT_RGB/Residential/Residential_
jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1741.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_296.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1594.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_282.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1580.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_269.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1219.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_533.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1231.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1557.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_255.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1543.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_241.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_527.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1225.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_279.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1209.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1221.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_523.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_245.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1547.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_251.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1553.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1235.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_537.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1584.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_286.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1590.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_292.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1779.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_709.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1745.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_721.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1023.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_735.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1037.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1751.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1989.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1962.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_906.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_912.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1976.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1786.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1792.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_669.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1619.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_133.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1631.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1157.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_655.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1143.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_899.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_641.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_127.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1625.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1816.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_872.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_866.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1802.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_16.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_696.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1194.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_682.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1180.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1369.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_319.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_457.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1355.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1433.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_331.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1427.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_325.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_443.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1341.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1396.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_494.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1382.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_480.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_481.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1383.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_495.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1397.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_324.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1426.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1340.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_442.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1354.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_456.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_330.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1432.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_318.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1368.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1181.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_683.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1195.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_697.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_867.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_17.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1803.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1817.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_873.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_640.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_898.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1142.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1624.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_126.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1630.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_132.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_654.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1156.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1618.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_668.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1793.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1787.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_913.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1977.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1963.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_907.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1036.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_734.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1988.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1750.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1744.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1022.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_720.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_708.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1778.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_293.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1591.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_287.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1585.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1552.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_250.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_536.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1234.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_522.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1220.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1546.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_244.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1208.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_278.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_508.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1578.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1236.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_534.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_252.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1550.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_246.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1544.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1222.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_520.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1593.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_291.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1587.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_285.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1008.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1752.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_736.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1034.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_722.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1020.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1746.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1975.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_911.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_905.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1961.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1949.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1791.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_939.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1785.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_118.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1168.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_124.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1626.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1140.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_642.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1154.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_656.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_130.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1632.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1801.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_9.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_15.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_865.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_871.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1815.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_29.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_681.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1183.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_859.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_695.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1197.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1829.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1418.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_468.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_440.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1342.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1424.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_326.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1430.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_332.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_454.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1356.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1381.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_483.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1395.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_497.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_496.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1394.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_482.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1380.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_333.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1431.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1357.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_455.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1343.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_441.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_327.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1425.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_469.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1419.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1196.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_694.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1828.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_28.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_858.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1182.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_680.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_870.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1814.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_14.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_8.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1800.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_864.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_657.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1155.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1633.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_131.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1627.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_125.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_643.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1141.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1169.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_119.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_938.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1784.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1790.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1948.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_904.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1960.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1974.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_910.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1021.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_723.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1747.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1753.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1035.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_737.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1009.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_284.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1586.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_290.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1592.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1545.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_247.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_521.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1223.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_535.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1237.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1551.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_253.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_1579.jpg
#   inflating: EuroSAT_RGB/Pasture/Pasture_509.jpg

# %%
class EurosatDataset(Dataset):

    def __init__(self, root, transform=None):
        self.root = Path(root)
        self.transform = transform

        self.classes = sorted([d.name for d in self.root.iterdir() if d.is_dir()])
        self.class_to_idx = {cls_name: i for i, cls_name in enumerate(self.classes)}

        self.samples = []
        for root, dirs, files in os.walk(root):
          for file in files:
            self.samples.append(root+'/'+file)

    def __getitem__(self, index):
        path = self.samples[index]
        img = Image.open(path)

        target = self.class_to_idx[Path(path).parts[-2]]

        if self.transform is not None:
             img = self.transform(img)

        return img, target

    def __len__(self):
        return len(self.samples)

# %%
batch_size = 16
dtype = torch.float
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device)

num_steps = 100
# Out:
# cuda

# %%
trans_comp = T.Compose([
  T.ToTensor(),
  T.Normalize((0,), (1,))
])

# %%
dataset = EurosatDataset(root = 'EuroSAT_RGB', transform=trans_comp)
train_dataset, test_dataset = random_split(dataset, [0.9, 0.1])
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle= True, drop_last=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

train_features, train_labels = next(iter(train_dataloader))

# %%
print(train_features.size())

print(train_labels.size())
img = train_features[1].squeeze()
plt.imshow(img.permute(1, 2, 0))
# Out:
# torch.Size([16, 3, 64, 64])
# torch.Size([16])

# %%
class MocoV2(LightningModule):

    def __init__(self, base_encoder, emb_dim, num_negatives, emb_spaces=1, *args, **kwargs):
        super().__init__()
        self.save_hyperparameters()

        # create the encoders
        template_model = getattr(torchvision.models, base_encoder)
        self.encoder_q = template_model(num_classes=self.hparams.emb_dim)
        self.encoder_k = template_model(num_classes=self.hparams.emb_dim)

        # remove fc layer
        self.encoder_q = nn.Sequential(*list(self.encoder_q.children())[:-1], nn.Flatten())
        self.encoder_k = nn.Sequential(*list(self.encoder_k.children())[:-1], nn.Flatten())

        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient

        # create the projection heads
        self.mlp_dim = 512 * (1 if base_encoder in ['resnet18', 'resnet34'] else 4)
        self.heads_q = nn.ModuleList([
            nn.Sequential(nn.Linear(self.mlp_dim, self.mlp_dim), nn.ReLU(), nn.Linear(self.mlp_dim, emb_dim))
            for _ in range(emb_spaces)
        ])
        self.heads_k = nn.ModuleList([
            nn.Sequential(nn.Linear(self.mlp_dim, self.mlp_dim), nn.ReLU(), nn.Linear(self.mlp_dim, emb_dim))
            for _ in range(emb_spaces)
        ])

        for param_q, param_k in zip(self.heads_q.parameters(), self.heads_k.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient

        # create the queue
        self.register_buffer("queue", torch.randn(emb_spaces, emb_dim, num_negatives))
        self.queue = nn.functional.normalize(self.queue, dim=1)

        self.register_buffer("queue_ptr", torch.zeros(emb_spaces, 1, dtype=torch.long))

    @torch.no_grad()
    def _momentum_update_key_encoder(self):
        """
        Momentum update of the key encoder
        """
        for param_q, param_k in zip(self.encoder_q.parameters(), self.encoder_k.parameters()):
            em = self.hparams.encoder_momentum
            param_k.data = param_k.data * em + param_q.data * (1. - em)
        for param_q, param_k in zip(self.heads_q.parameters(), self.heads_k.parameters()):
            em = self.hparams.encoder_momentum
            param_k.data = param_k.data * em + param_q.data * (1. - em)

    @torch.no_grad()
    def _dequeue_and_enqueue(self, keys, queue_idx):
        # gather keys before updating queue
        if self.use_ddp or self.use_ddp2:
            keys = concat_all_gather(keys)

        batch_size = keys.shape[0]

        ptr = int(self.queue_ptr[queue_idx])
        assert self.hparams.num_negatives % batch_size == 0  # for simplicity

        # replace the keys at ptr (dequeue and enqueue)
        self.queue[queue_idx, :, ptr:ptr + batch_size] = keys.T
        ptr = (ptr + batch_size) % self.hparams.num_negatives  # move pointer

        self.queue_ptr[queue_idx] = ptr

    def forward(self, img_q, img_k):
        """
        Input:
            img_q: a batch of query images
            img_k: a batch of key images
        Output:
            logits, targets
        """

        # update the key encoder
        self._momentum_update_key_encoder()

        # compute query features
        v_q = self.encoder_q(img_q)

        # compute key features
        v_k = []
        for i in range(self.hparams.emb_spaces):
            # shuffle for making use of BN
            if self.use_ddp or self.use_ddp2:
                img_k[i], idx_unshuffle = batch_shuffle_ddp(img_k[i])

            with torch.no_grad():  # no gradient to keys
                v_k.append(self.encoder_k(img_k[i]))

            # undo shuffle
            if self.use_ddp or self.use_ddp2:
                v_k[i] = batch_unshuffle_ddp(v_k[i], idx_unshuffle)

        logits = []
        for i in range(self.hparams.emb_spaces):
            # compute query projections
            z_q = self.heads_q[i](v_q)  # queries: NxC
            z_q = nn.functional.normalize(z_q, dim=1)

            # compute key projections
            z_k = []
            for j in range(self.hparams.emb_spaces):
                with torch.no_grad():  # no gradient to keys
                    z_k.append(self.heads_k[i](v_k[j]))  # keys: NxC
                    z_k[j] = nn.functional.normalize(z_k[j], dim=1)

            # select positive and negative pairs
            z_pos = z_k[i]
            z_neg = self.queue[i].clone().detach()
            if i > 0:  # embedding space 0 is invariant to all augmentations
                z_neg = torch.cat([z_neg, *[z_k[j].T for j in range(self.hparams.emb_spaces) if j != i]], dim=1)

            # compute logits
            # Einstein sum is more intuitive
            l_pos = torch.einsum('nc,nc->n', z_q, z_pos).unsqueeze(-1)  # positive logits: Nx1
            l_neg = torch.einsum('nc,ck->nk', z_q, z_neg)  # negative logits: NxK

            l = torch.cat([l_pos, l_neg], dim=1)  # logits: Nx(1+K)
            l /= self.hparams.softmax_temperature  # apply temperature
            logits.append(l)

            # dequeue and enqueue
            self._dequeue_and_enqueue(z_k[i], queue_idx=i)

        # targets: positive key indicators
        targets = torch.zeros(logits[0].shape[0], dtype=torch.long)
        targets = targets.type_as(logits[0])

        return logits, targets

    def training_step(self, batch, batch_idx):
        img_q, img_k = batch
        if self.hparams.emb_spaces == 1 and isinstance(img_k, torch.Tensor):
            img_k = [img_k]

        output, target = self(img_q, img_k)

        losses = []
        accuracies = []
        for out in output:
            losses.append(F.cross_entropy(out.float(), target.long()))
            accuracies.append(precision_at_k(out, target, top_k=(1,))[0])
        loss = torch.sum(torch.stack(losses))

        log = {'train_loss': loss}
        for i, acc in enumerate(accuracies):
            log[f'train_acc/subspace{i}'] = acc

        self.log_dict(log, on_step=True, on_epoch=False, prog_bar=True)
        return loss

    def configure_optimizers(self):
        params = chain(self.encoder_q.parameters(), self.heads_q.parameters())
        optimizer = optim.SGD(params, self.hparams.learning_rate,
                              momentum=self.hparams.momentum,
                              weight_decay=self.hparams.weight_decay)
        return optimizer

    @staticmethod
    def add_model_specific_args(parent_parser):
        parser = ArgumentParser(parents=[parent_parser], add_help=False)
        parser.add_argument('--base_encoder', type=str, default='resnet18')
        parser.add_argument('--emb_dim', type=int, default=128)
        parser.add_argument('--num_workers', type=int, default=32)
        parser.add_argument('--num_negatives', type=int, default=16384)
        parser.add_argument('--encoder_momentum', type=float, default=0.999)
        parser.add_argument('--softmax_temperature', type=float, default=0.07)
        parser.add_argument('--learning_rate', type=float, default=0.03)
        parser.add_argument('--momentum', type=float, default=0.9)
        parser.add_argument('--weight_decay', type=float, default=1e-4)
        parser.add_argument('--batch_size', type=int, default=256)
        return parser

# %%
model = MocoV2.load_from_checkpoint("gdrive/MyDrive/seco_resnet18_1m.ckpt")
backbone = deepcopy(model.encoder_q)
backbone.cuda()
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/utilities/migration/migration.py:195: PossibleUserWarning: You have multiple `ModelCheckpoint` callback states in this checkpoint, but we found state keys that would end up colliding with each other after an upgrade, which means we can't differentiate which of your checkpoint callbacks needs which states. At least one of your `ModelCheckpoint` callbacks will not be able to reload the state.
#   rank_zero_warn(
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.1.4 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file gdrive/MyDrive/seco_resnet18_1m.ckpt`
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (5): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (6): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (7): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
#   (9): Flatten(start_dim=1, end_dim=-1)
# )

# %%
def forward_pass(net, num_steps, data, backbone):
  #data = data.view(batch_size, -1)
  with torch.no_grad():
    feats = backbone(data)
  mem_rec = []
  spk_rec = []
  utils.reset(net)  # resets hidden states for all LIF neurons in net
  spike_data = spikegen.rate(feats, num_steps=num_steps, gain=1)

  for step in range(num_steps):
      spk_out, mem_out = net(spike_data[0])
      spk_rec.append(spk_out)
      mem_rec.append(mem_out)

  return torch.stack(spk_rec), torch.stack(mem_rec)

# %%
loss_fn = SF.ce_count_loss()
num_steps = 10

# %%
def batch_accuracy(train_loader, net, num_steps):
  with torch.no_grad():
    total = 0
    acc = 0
    net.eval()

    train_loader = iter(train_loader)
    for data, targets in train_loader:
      data = data.to(device)
      targets = targets.to(device)
      spk_rec, _ = forward_pass(net, num_steps, data, backbone)

      acc += SF.accuracy_rate(spk_rec, targets) * spk_rec.size(1)
      total += spk_rec.size(1)

  return acc/total

# %%
def train():

  hidden = 2048
  hidden2 = 4096

  output = 10

  init_alpha = torch.rand(hidden)
  init_beta = torch.rand(hidden)

  init_alpha2 = torch.rand(hidden2)
  init_beta2 = torch.rand(hidden2)

  out_alpha = torch.rand(output)
  out_beta = torch.rand(output)

  net = nn.Sequential(nn.Linear(512, hidden),
                      snn.Leaky(beta=init_beta, learn_beta=True, learn_threshold=True, init_hidden=True),
                      nn.Linear(hidden, hidden2),
                      snn.Leaky(beta=init_beta2, learn_beta=True, learn_threshold=True, init_hidden=True),
                      nn.Linear(hidden2, hidden),
                      snn.Leaky(beta=init_beta, learn_beta=True, learn_threshold=True, init_hidden=True),
                      nn.Linear(hidden, output),
                      snn.Leaky(beta=out_beta, learn_beta=True, learn_threshold=True, init_hidden=True, output=True)
                      ).to(device)
  optimizer = torch.optim.Adam(net.parameters(), lr=1e-5)
  num_epochs = 100
  loss_hist = []
  test_acc_hist = []
  epoch_counter = 0

  # Outer training loop
  for epoch in range(num_epochs):

      epoch_counter += 1
      counter = 0

      if epoch_counter == 60 or epoch_counter == 80:
        for g in optim.param_groups:
          g['lr'] = g['lr']/10

      # Training loop
      for data, targets in iter(train_dataloader):
          data = data.to(device)
          targets = targets.to(device)

          # forward pass
          net.train()
          spk_rec, _ = forward_pass(net, num_steps, data, backbone)
          # initialize the loss & sum over time
          loss_val = loss_fn(spk_rec, targets)

          # Gradient calculation + weight update
          optimizer.zero_grad()
          loss_val.backward()
          optimizer.step()

          # Store loss history for future plotting
          loss_hist.append(loss_val.item())

          # Test set
          if counter == 1000:
            with torch.no_grad():
                net.eval()

                # Test set forward pass
                test_acc = batch_accuracy(test_dataloader, net, num_steps)
                print(f"Epoch {epoch_counter}, Iteration {counter}, Test Acc: {test_acc * 100:.2f}%\n")
                test_acc_hist.append(test_acc.item())

          counter += 1

  return net

# %%
def test(alpha, beta, net):
  with torch.no_grad():
      net.eval()
      test_acc = batch_accuracy(test_dataloader, net, num_steps)
      print(f"Alpha {alpha}, Beta {beta}, Test Acc: {test_acc * 100:.2f}%")

# %%
time_start = time.time()
train()
print(time.time()-time_start, "seconds\n")
# Out:
# Epoch 1, Iteration 1000, Test Acc: 43.30%
#
# Epoch 2, Iteration 1000, Test Acc: 64.29%
#
# Epoch 3, Iteration 1000, Test Acc: 70.16%
#
# Epoch 4, Iteration 1000, Test Acc: 71.54%
#
# Epoch 5, Iteration 1000, Test Acc: 74.74%
